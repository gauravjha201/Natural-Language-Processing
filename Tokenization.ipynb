# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravjha201/Natural-Language-Processing/blob/main/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
corpus="""hello welcome, to krishna's world.
krishna is a good boy.
he is a good boy!.
he try to learn new things.
he is smart

"""

# %%
corpus
# Out:
# "hello welcome, to krishna's world.\nkrishna is a good boy.\nhe is a good boy!.\nhe try to learn new things.\nhe is smart \n\n"

# %%
# !pip install nltk

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sentences=sent_tokenize(corpus)
sentences
# Out:
# ["hello welcome, to krishna's world.",
#  'krishna is a good boy.',
#  'he is a good boy!.',
#  'he try to learn new things.',
#  'he is smart']

# %%
words=word_tokenize(corpus)
words
# Out:
# ['hello',
#  'welcome',
#  ',',
#  'to',
#  'krishna',
#  "'s",
#  'world',
#  '.',
#  'krishna',
#  'is',
#  'a',
#  'good',
#  'boy',
#  '.',
#  'he',
#  'is',
#  'a',
#  'good',
#  'boy',
#  '!',
#  '.',
#  'he',
#  'try',
#  'to',
#  'learn',
#  'new',
#  'things',
#  '.',
#  'he',
#  'is',
#  'smart']

# %%
from nltk import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['hello',
#  'welcome',
#  ',',
#  'to',
#  'krishna',
#  "'",
#  's',
#  'world',
#  '.',
#  'krishna',
#  'is',
#  'a',
#  'good',
#  'boy',
#  '.',
#  'he',
#  'is',
#  'a',
#  'good',
#  'boy',
#  '!.',
#  'he',
#  'try',
#  'to',
#  'learn',
#  'new',
#  'things',
#  '.',
#  'he',
#  'is',
#  'smart']
